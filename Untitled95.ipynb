# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Load your data into a pandas DataFrame
data = pd.read_csv('resource1.csv')

# Combine 'NICName' and 'IndiaStates' columns into a single text column
data['Text'] = data['NICName'] + ' ' + data['IndiaStates']

# Convert text data into numerical vectors using TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')
X_tfidf = vectorizer.fit_transform(data['Text'])

# Apply PCA to reduce dimensionality of the TF-IDF vectors
pca = PCA(n_components=1)  # You can adjust the number of components as needed
X_pca = pca.fit_transform(X_tfidf.toarray())

# Apply K-means clustering to group similar businesses based on PCA-transformed data
num_clusters = 5  # You can adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X_pca)

# Get cluster assignments for each data point
data['Cluster'] = kmeans.labels_

# Evaluate the clustering performance using silhouette score
silhouette_avg = silhouette_score(X_pca, kmeans.labels_)
print(f'Silhouette Score: {silhouette_avg}')

# Display the top terms (features) for each cluster
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()  # Use get_feature_names_out() instead of get_feature_names()
for i in range(num_clusters):
    print(f"Cluster {i+1} Top Terms:", [terms[ind] for ind in order_centroids[i, :5]])

# You can further analyze the clusters and interpret the results based on the business categories.

# Example: Print samples from each cluster
for i in range(num_clusters):
    print(f"\nCluster {i+1} Samples:")
    print(data[data['Cluster'] == i].head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score: 0.7139639912138425
# Cluster 1 Top Terms: ['accessories']
# Cluster 2 Top Terms: ['accessories']
# Cluster 3 Top Terms: ['accessories']
# Cluster 4 Top Terms: ['accessories']
# Cluster 5 Top Terms: ['accessories']
#
# Cluster 1 Samples:
#             IndiaStates                                            NICName  \
# 1  STATE - NCT OF DELHI                     Growing of non-perennial crops
# 2  STATE - NCT OF DELHI  Growing of cereals (except rice), leguminous c...
# 3  STATE - NCT OF DELHI                                    Growing of rice
# 4  STATE - NCT OF DELHI  Growing of vegetables and melons, roots and tu...
# 5  STATE - NCT OF DELHI                             Growing of fibre crops
#
#    MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 1                      169                    151                       18
# 2                       83                     81                        2
# 3                        9                      9                        0
# 4                       42                     34                        8
# 5                        6                      6                        0
#
#    MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 1                       17                     15                        2
# 2                        9                      7                        2
# 3                        0                      0                        0
# 4                        7                      7                        0
# 5                        0                      0                        0
#
#    MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 1                      152                    136  ...
# 2                       74                     74  ...
# 3                        9                      9  ...
# 4                       35                     27  ...
# 5                        6                      6  ...
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 1                            2                           78
# 2                            2                           29
# 3                            0                            0
# 4                            0                           46
# 5                            0                            0
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 1                         53                           25           261
# 2                         21                            8           120
# 3                          0                            0             9
# 4                         29                           17            94
# 5                          0                            0             6
#
#    MaleFemaleRatio   Latitude  Longitude  \
# 1         8.388889  10.705690  92.487468
# 2        40.500000  17.233496  81.722599
# 3         9.000000  17.233496  81.722599
# 4         4.250000  14.718758  79.659610
# 5         6.000000  18.110744  83.386585
#
#                                                 Text  Cluster
# 1  Growing of non-perennial crops STATE - NCT OF ...        0
# 2  Growing of cereals (except rice), leguminous c...        0
# 3               Growing of rice STATE - NCT OF DELHI        0
# 4  Growing of vegetables and melons, roots and tu...        0
# 5        Growing of fibre crops STATE - NCT OF DELHI        0
#
# [5 rows x 26 columns]
#
# Cluster 2 Samples:
#               IndiaStates                                            NICName  \
# 355  STATE - NCT OF DELHI              Retail sale in non-specialized stores
# 356  STATE - NCT OF DELHI  Retail sale in non-specialized stores with foo...
# 357  STATE - NCT OF DELHI        Other retail sale in non-specialized stores
# 358  STATE - NCT OF DELHI  Retail sale of food, beverages and tobacco in ...
# 359  STATE - NCT OF DELHI          Retail sale of food in specialized stores
#
#      MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 355                     1102                   1034                       68
# 356                      251                    228                       23
# 357                      851                    806                       45
# 358                    18936                  17254                     1682
# 359                    18738                  17069                     1669
#
#      MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 355                       13                     13                        0
# 356                        0                      0                        0
# 357                       13                     13                        0
# 358                      415                    323                       92
# 359                      403                    311                       92
#
#      MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 355                     1089                   1021  ...
# 356                      251                    228  ...
# 357                      838                    793  ...
# 358                    18521                  16931  ...
# 359                    18335                  16758  ...
#
#      MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 355                            0                           62
# 356                            0                            8
# 357                            0                           54
# 358                           18                          833
# 359                           18                          819
#
#      MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 355                         62                            0          1164
# 356                          8                            0           259
# 357                         54                            0           905
# 358                        634                          199         19808
# 359                        622                          197         19596
#
#      MaleFemaleRatio   Latitude  Longitude  \
# 355        15.205882  21.159662  79.652738
# 356         9.913043  21.338685  74.234482
# 357        17.911111  19.964842  79.291473
# 358        10.258026  16.575683  74.312560
# 359        10.227082  17.667877  75.906727
#
#                                                   Text  Cluster
# 355  Retail sale in non-specialized stores STATE - ...        1
# 356  Retail sale in non-specialized stores with foo...        1
# 357  Other retail sale in non-specialized stores ST...        1
# 358  Retail sale of food, beverages and tobacco in ...        1
# 359  Retail sale of food in specialized stores STAT...        1
#
# [5 rows x 26 columns]
#
# Cluster 3 Samples:
#               IndiaStates                                            NICName  \
# 317  STATE - NCT OF DELHI                Specialized construction activities
# 325  STATE - NCT OF DELHI          Other specialized construction activities
# 326  STATE - NCT OF DELHI          Other specialized construction activities
# 327  STATE - NCT OF DELHI  Wholesale and retail trade and repair of motor...
# 328  STATE - NCT OF DELHI                             Sale of motor vehicles
#
#      MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 317                    18378                  18079                      299
# 325                       74                     71                        3
# 326                       74                     71                        3
# 327                    13130                  12891                      239
# 328                     1265                   1200                       65
#
#      MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 317                      384                    375                        9
# 325                        0                      0                        0
# 326                        0                      0                        0
# 327                      209                    205                        4
# 328                       19                     15                        4
#
#      MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 317                    17994                  17704  ...
# 325                       74                     71  ...
# 326                       74                     71  ...
# 327                    12921                  12686  ...
# 328                     1246                   1185  ...
#
#      MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 317                            6                         2092
# 325                            0                            0
# 326                            0                            0
# 327                            0                          496
# 328                            0                           50
#
#      MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 317                       2015                           77         20565
# 325                          0                            0            74
# 326                          0                            0            74
# 327                        480                           16         13640
# 328                         44                            6          1315
#
#      MaleFemaleRatio   Latitude  Longitude  \
# 317        60.464883  22.701856  75.866635
# 325        23.666667  22.946009  81.075174
# 326        23.666667  25.375241  77.828119
# 327        53.937238  26.200000  78.200000
# 328        18.461538  26.200000  78.200000
#
#                                                   Text  Cluster
# 317  Specialized construction activities STATE - NC...        2
# 325  Other specialized construction activities STAT...        2
# 326  Other specialized construction activities STAT...        2
# 327  Wholesale and retail trade and repair of motor...        2
# 328        Sale of motor vehicles STATE - NCT OF DELHI        2
#
# [5 rows x 26 columns]
#
# Cluster 4 Samples:
#              IndiaStates                                            NICName  \
# 0   STATE - NCT OF DELHI  Crop and animal production, hunting and relate...
# 22  STATE - NCT OF DELHI  Support activities to agriculture and post-har...
# 23  STATE - NCT OF DELHI             Support activities for crop production
# 24  STATE - NCT OF DELHI           Support activities for animal production
# 25  STATE - NCT OF DELHI                       Post-harvest crop activities
#
#     MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 0                      1484                   1271                      213
# 22                      443                    398                       45
# 23                      391                    351                       40
# 24                        6                      6                        0
# 25                       46                     41                        5
#
#     MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 0                       179                    128                       51
# 22                       35                     34                        1
# 23                       24                     23                        1
# 24                        6                      6                        0
# 25                        5                      5                        0
#
#     MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 0                      1305                   1143  ...
# 22                      408                    364  ...
# 23                      367                    328  ...
# 24                        0                      0  ...
# 25                       41                     36  ...
#
#     MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                            10                          201
# 22                            0                           67
# 23                            0                           52
# 24                            0                            0
# 25                            0                           15
#
#     MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 0                         137                           64          1708
# 22                         49                           18           511
# 23                         37                           15           444
# 24                          0                            0             6
# 25                         12                            3            61
#
#     MaleFemaleRatio   Latitude  Longitude  \
# 0          5.967136  10.705690  92.487468
# 22         8.844444  27.501344  96.524294
# 23         8.775000  27.986368  93.157835
# 24         6.000000  28.477492  94.816557
# 25         8.200000  28.477492  94.816557
#
#                                                  Text  Cluster
# 0   Crop and animal production, hunting and relate...        3
# 22  Support activities to agriculture and post-har...        3
# 23  Support activities for crop production STATE -...        3
# 24  Support activities for animal production STATE...        3
# 25  Post-harvest crop activities STATE - NCT OF DELHI        3
#
# [5 rows x 26 columns]
#
# Cluster 5 Samples:
#               IndiaStates                                            NICName  \
# 362  STATE - NCT OF DELHI  Retail sale of automotive fuel in specialized ...
# 363  STATE - NCT OF DELHI  Retail sale of automotive fuel in specialized ...
# 364  STATE - NCT OF DELHI  Retail sale of information and communications ...
# 366  STATE - NCT OF DELHI  Retail sale of audio and video equipment in sp...
# 369  STATE - NCT OF DELHI  Retail sale of hardware, paints and glass in s...
#
#      MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 362                      972                    936                       36
# 363                      972                    936                       36
# 364                     2812                   2689                      123
# 366                       81                     78                        3
# 369                     3458                   3397                       61
#
#      MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 362                       25                     23                        2
# 363                       25                     23                        2
# 364                       34                     34                        0
# 366                        0                      0                        0
# 369                       53                     53                        0
#
#      MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 362                      947                    913  ...
# 363                      947                    913  ...
# 364                     2778                   2655  ...
# 366                       81                     78  ...
# 369                     3405                   3344  ...
#
#      MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 362                            0                           57
# 363                            0                           57
# 364                            0                          157
# 366                            0                            6
# 369                            0                          179
#
#      MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 362                         57                            0          1029
# 363                         57                            0          1029
# 364                        136                           21          2977
# 366                          6                            0            87
# 369                        170                            9          3637
#
#      MaleFemaleRatio   Latitude  Longitude  \
# 362        26.000000  20.925734  74.777139
# 363        26.000000  20.737756  78.603168
# 364        21.861789  19.271371  76.764481
# 366        26.000000  19.722232  77.154477
# 369        55.688525  18.187880  76.035779
#
#                                                   Text  Cluster
# 362  Retail sale of automotive fuel in specialized ...        4
# 363  Retail sale of automotive fuel in specialized ...        4
# 364  Retail sale of information and communications ...        4
# 366  Retail sale of audio and video equipment in sp...        4
# 369  Retail sale of hardware, paints and glass in s...        4
#
# [5 rows x 26 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Load your data into a pandas DataFrame
data = pd.read_csv('resource1.csv')

# Combine 'NICName' and 'IndiaStates' columns into a single text column
data['Text'] = data['NICName'] + ' ' + data['IndiaStates']

# Convert text data into numerical vectors using TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')
X_tfidf = vectorizer.fit_transform(data['Text'])

# Apply PCA to reduce dimensionality of the TF-IDF vectors
pca = PCA(n_components=1)  # You can adjust the number of components as needed
X_pca = pca.fit_transform(X_tfidf.toarray())

# Apply K-means clustering to group similar businesses based on PCA-transformed data
num_clusters = 5  # You can adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X_pca)

# Get cluster assignments for each data point
data['Cluster'] = kmeans.labels_

# Evaluate the clustering performance using silhouette score
silhouette_avg = silhouette_score(X_pca, kmeans.labels_)
print(f'Silhouette Score: {silhouette_avg}')

# Display the top terms (features) for each cluster
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()  # Use get_feature_names_out() instead of get_feature_names()
for i in range(num_clusters):
    print(f"Cluster {i+1} Top Terms:", [terms[ind] for ind in order_centroids[i, :5]])

# Example: Print samples from each cluster
for i in range(num_clusters):
    print(f"\nCluster {i+1} Samples:")
    print(data[data['Cluster'] == i][['MainWorkersTotalPersons', 'Cluster']].head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score: 0.7138715406463305
# Cluster 1 Top Terms: ['accessories']
# Cluster 2 Top Terms: ['accessories']
# Cluster 3 Top Terms: ['accessories']
# Cluster 4 Top Terms: ['accessories']
# Cluster 5 Top Terms: ['accessories']
#
# Cluster 1 Samples:
#      MainWorkersTotalPersons  Cluster
# 317                    18378        0
# 325                       74        0
# 326                       74        0
# 327                    13130        0
# 328                     1265        0
#
# Cluster 2 Samples:
#      MainWorkersTotalPersons  Cluster
# 355                     1102        1
# 356                      251        1
# 357                      851        1
# 358                    18936        1
# 359                    18738        1
#
# Cluster 3 Samples:
#     MainWorkersTotalPersons  Cluster
# 0                      1484        2
# 22                      443        2
# 23                      391        2
# 24                        6        2
# 25                       46        2
#
# Cluster 4 Samples:
#    MainWorkersTotalPersons  Cluster
# 1                      169        3
# 2                       83        3
# 3                        9        3
# 4                       42        3
# 5                        6        3
#
# Cluster 5 Samples:
#      MainWorkersTotalPersons  Cluster
# 362                      972        4
# 363                      972        4
# 364                     2812        4
# 366                       81        4
# 369                     3458        4

# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# Load your data into a pandas DataFrame
data = pd.read_csv('resource1.csv')

# Combine 'NICName' and 'IndiaStates' columns into a single text column
data['Text'] = data['NICName'] + ' ' + data['IndiaStates']

# Convert text data into numerical vectors using TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')
X_tfidf = vectorizer.fit_transform(data['Text'])

# Apply PCA to reduce dimensionality of the TF-IDF vectors
pca = PCA(n_components=1)  # You can adjust the number of components as needed
X_pca = pca.fit_transform(X_tfidf.toarray())

# Apply MiniBatchKMeans clustering to group similar businesses based on PCA-transformed data
num_clusters = 5  # You can adjust the number of clusters as needed
kmeans = MiniBatchKMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X_pca)

# Get cluster assignments for each data point
data['Cluster'] = kmeans.labels_

# Evaluate the clustering performance using silhouette score
silhouette_avg = silhouette_score(X_pca, kmeans.labels_)
print(f'Silhouette Score: {silhouette_avg}')

# Display the top terms (features) for each cluster
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()  # Use get_feature_names_out() instead of get_feature_names()
for i in range(num_clusters):
    print(f"Cluster {i+1} Top Terms:", [terms[ind] for ind in order_centroids[i, :5]])

# Example: Print samples from each cluster
for i in range(num_clusters):
    print(f"\nCluster {i+1} Test Samples:")
    test_samples = data.iloc[np.where(kmeans.predict(X_pca) == i)]
    print(test_samples.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Silhouette Score: 0.7104488689103636
# Cluster 1 Top Terms: ['accessories']
# Cluster 2 Top Terms: ['accessories']
# Cluster 3 Top Terms: ['accessories']
# Cluster 4 Top Terms: ['accessories']
# Cluster 5 Top Terms: ['accessories']
#
# Cluster 1 Test Samples:
#              IndiaStates                                            NICName  \
# 0   STATE - NCT OF DELHI  Crop and animal production, hunting and relate...
# 22  STATE - NCT OF DELHI  Support activities to agriculture and post-har...
# 23  STATE - NCT OF DELHI             Support activities for crop production
# 24  STATE - NCT OF DELHI           Support activities for animal production
# 25  STATE - NCT OF DELHI                       Post-harvest crop activities
#
#     MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 0                      1484                   1271                      213
# 22                      443                    398                       45
# 23                      391                    351                       40
# 24                        6                      6                        0
# 25                       46                     41                        5
#
#     MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 0                       179                    128                       51
# 22                       35                     34                        1
# 23                       24                     23                        1
# 24                        6                      6                        0
# 25                        5                      5                        0
#
#     MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 0                      1305                   1143  ...
# 22                      408                    364  ...
# 23                      367                    328  ...
# 24                        0                      0  ...
# 25                       41                     36  ...
#
#     MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                            10                          201
# 22                            0                           67
# 23                            0                           52
# 24                            0                            0
# 25                            0                           15
#
#     MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 0                         137                           64          1708
# 22                         49                           18           511
# 23                         37                           15           444
# 24                          0                            0             6
# 25                         12                            3            61
#
#     MaleFemaleRatio   Latitude  Longitude  \
# 0          5.967136  10.705690  92.487468
# 22         8.844444  27.501344  96.524294
# 23         8.775000  27.986368  93.157835
# 24         6.000000  28.477492  94.816557
# 25         8.200000  28.477492  94.816557
#
#                                                  Text  Cluster
# 0   Crop and animal production, hunting and relate...        0
# 22  Support activities to agriculture and post-har...        0
# 23  Support activities for crop production STATE -...        0
# 24  Support activities for animal production STATE...        0
# 25  Post-harvest crop activities STATE - NCT OF DELHI        0
#
# [5 rows x 26 columns]
#
# Cluster 2 Test Samples:
#               IndiaStates                                            NICName  \
# 362  STATE - NCT OF DELHI  Retail sale of automotive fuel in specialized ...
# 363  STATE - NCT OF DELHI  Retail sale of automotive fuel in specialized ...
# 364  STATE - NCT OF DELHI  Retail sale of information and communications ...
# 366  STATE - NCT OF DELHI  Retail sale of audio and video equipment in sp...
# 369  STATE - NCT OF DELHI  Retail sale of hardware, paints and glass in s...
#
#      MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 362                      972                    936                       36
# 363                      972                    936                       36
# 364                     2812                   2689                      123
# 366                       81                     78                        3
# 369                     3458                   3397                       61
#
#      MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 362                       25                     23                        2
# 363                       25                     23                        2
# 364                       34                     34                        0
# 366                        0                      0                        0
# 369                       53                     53                        0
#
#      MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 362                      947                    913  ...
# 363                      947                    913  ...
# 364                     2778                   2655  ...
# 366                       81                     78  ...
# 369                     3405                   3344  ...
#
#      MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 362                            0                           57
# 363                            0                           57
# 364                            0                          157
# 366                            0                            6
# 369                            0                          179
#
#      MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 362                         57                            0          1029
# 363                         57                            0          1029
# 364                        136                           21          2977
# 366                          6                            0            87
# 369                        170                            9          3637
#
#      MaleFemaleRatio   Latitude  Longitude  \
# 362        26.000000  20.925734  74.777139
# 363        26.000000  20.737756  78.603168
# 364        21.861789  19.271371  76.764481
# 366        26.000000  19.722232  77.154477
# 369        55.688525  18.187880  76.035779
#
#                                                   Text  Cluster
# 362  Retail sale of automotive fuel in specialized ...        1
# 363  Retail sale of automotive fuel in specialized ...        1
# 364  Retail sale of information and communications ...        1
# 366  Retail sale of audio and video equipment in sp...        1
# 369  Retail sale of hardware, paints and glass in s...        1
#
# [5 rows x 26 columns]
#
# Cluster 3 Test Samples:
#             IndiaStates                                            NICName  \
# 1  STATE - NCT OF DELHI                     Growing of non-perennial crops
# 2  STATE - NCT OF DELHI  Growing of cereals (except rice), leguminous c...
# 3  STATE - NCT OF DELHI                                    Growing of rice
# 4  STATE - NCT OF DELHI  Growing of vegetables and melons, roots and tu...
# 5  STATE - NCT OF DELHI                             Growing of fibre crops
#
#    MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 1                      169                    151                       18
# 2                       83                     81                        2
# 3                        9                      9                        0
# 4                       42                     34                        8
# 5                        6                      6                        0
#
#    MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 1                       17                     15                        2
# 2                        9                      7                        2
# 3                        0                      0                        0
# 4                        7                      7                        0
# 5                        0                      0                        0
#
#    MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 1                      152                    136  ...
# 2                       74                     74  ...
# 3                        9                      9  ...
# 4                       35                     27  ...
# 5                        6                      6  ...
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 1                            2                           78
# 2                            2                           29
# 3                            0                            0
# 4                            0                           46
# 5                            0                            0
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 1                         53                           25           261
# 2                         21                            8           120
# 3                          0                            0             9
# 4                         29                           17            94
# 5                          0                            0             6
#
#    MaleFemaleRatio   Latitude  Longitude  \
# 1         8.388889  10.705690  92.487468
# 2        40.500000  17.233496  81.722599
# 3         9.000000  17.233496  81.722599
# 4         4.250000  14.718758  79.659610
# 5         6.000000  18.110744  83.386585
#
#                                                 Text  Cluster
# 1  Growing of non-perennial crops STATE - NCT OF ...        2
# 2  Growing of cereals (except rice), leguminous c...        2
# 3               Growing of rice STATE - NCT OF DELHI        2
# 4  Growing of vegetables and melons, roots and tu...        2
# 5        Growing of fibre crops STATE - NCT OF DELHI        2
#
# [5 rows x 26 columns]
#
# Cluster 4 Test Samples:
#               IndiaStates                                            NICName  \
# 327  STATE - NCT OF DELHI  Wholesale and retail trade and repair of motor...
# 328  STATE - NCT OF DELHI                             Sale of motor vehicles
# 329  STATE - NCT OF DELHI                             Sale of motor vehicles
# 330  STATE - NCT OF DELHI        Sale of motor vehicle parts and accessories
# 331  STATE - NCT OF DELHI        Sale of motor vehicle parts and accessories
#
#      MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 327                    13130                  12891                      239
# 328                     1265                   1200                       65
# 329                     1265                   1200                       65
# 330                     1745                   1663                       82
# 331                     1745                   1663                       82
#
#      MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 327                      209                    205                        4
# 328                       19                     15                        4
# 329                       19                     15                        4
# 330                       12                     12                        0
# 331                       12                     12                        0
#
#      MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 327                    12921                  12686  ...
# 328                     1246                   1185  ...
# 329                     1246                   1185  ...
# 330                     1733                   1651  ...
# 331                     1733                   1651  ...
#
#      MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 327                            0                          496
# 328                            0                           50
# 329                            0                           50
# 330                            0                           61
# 331                            0                           61
#
#      MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 327                        480                           16         13640
# 328                         44                            6          1315
# 329                         44                            6          1315
# 330                         58                            3          1806
# 331                         58                            3          1806
#
#      MaleFemaleRatio   Latitude  Longitude  \
# 327        53.937238  26.200000  78.200000
# 328        18.461538  26.200000  78.200000
# 329        18.461538  26.200000  78.200000
# 330        20.280488  25.557503  78.146610
# 331        20.280488  23.168925  80.033081
#
#                                                   Text  Cluster
# 327  Wholesale and retail trade and repair of motor...        3
# 328        Sale of motor vehicles STATE - NCT OF DELHI        3
# 329        Sale of motor vehicles STATE - NCT OF DELHI        3
# 330  Sale of motor vehicle parts and accessories ST...        3
# 331  Sale of motor vehicle parts and accessories ST...        3
#
# [5 rows x 26 columns]
#
# Cluster 5 Test Samples:
#               IndiaStates                                            NICName  \
# 355  STATE - NCT OF DELHI              Retail sale in non-specialized stores
# 356  STATE - NCT OF DELHI  Retail sale in non-specialized stores with foo...
# 357  STATE - NCT OF DELHI        Other retail sale in non-specialized stores
# 358  STATE - NCT OF DELHI  Retail sale of food, beverages and tobacco in ...
# 359  STATE - NCT OF DELHI          Retail sale of food in specialized stores
#
#      MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 355                     1102                   1034                       68
# 356                      251                    228                       23
# 357                      851                    806                       45
# 358                    18936                  17254                     1682
# 359                    18738                  17069                     1669
#
#      MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 355                       13                     13                        0
# 356                        0                      0                        0
# 357                       13                     13                        0
# 358                      415                    323                       92
# 359                      403                    311                       92
#
#      MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 355                     1089                   1021  ...
# 356                      251                    228  ...
# 357                      838                    793  ...
# 358                    18521                  16931  ...
# 359                    18335                  16758  ...
#
#      MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 355                            0                           62
# 356                            0                            8
# 357                            0                           54
# 358                           18                          833
# 359                           18                          819
#
#      MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales  TotalWorkers  \
# 355                         62                            0          1164
# 356                          8                            0           259
# 357                         54                            0           905
# 358                        634                          199         19808
# 359                        622                          197         19596
#
#      MaleFemaleRatio   Latitude  Longitude  \
# 355        15.205882  21.159662  79.652738
# 356         9.913043  21.338685  74.234482
# 357        17.911111  19.964842  79.291473
# 358        10.258026  16.575683  74.312560
# 359        10.227082  17.667877  75.906727
#
#                                                   Text  Cluster
# 355  Retail sale in non-specialized stores STATE - ...        4
# 356  Retail sale in non-specialized stores with foo...        4
# 357  Other retail sale in non-specialized stores ST...        4
# 358  Retail sale of food, beverages and tobacco in ...        4
# 359  Retail sale of food in specialized stores STAT...        4
#
# [5 rows x 26 columns]
